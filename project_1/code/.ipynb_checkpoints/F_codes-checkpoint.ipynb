# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# According to the [Meteorological Services Singapore](http://www.weather.gov.sg/climate-climate-of-singapore/#:~:text=Singapore%20is%20situated%20near%20the,month%2Dto%2Dmonth%20variation.), Singapore has typical tropical climate with adundant rainfall, high and uniform temperatures and high humidity all year round, since its situated near the equator. There are many factors that help us understand the climate of a country and in this project we are going to look into a few, especially rainfall.
#
# Singapore’s climate is characterised by two main monsoon seasons separated by inter-monsoonal periods.  The **Northeast Monsoon** occurs from December to early March, and the **Southwest Monsoon** from June to September.
#
# The major weather systems affecting Singapore that can lead to heavy rainfall are:
#
# -Monsoon surges, or strong wind episodes in the Northeast Monsoon flow bringing about major rainfall events;
#
# -Sumatra squalls, an organised line of thunderstorms travelling eastward across Singapore, having developed over the island of Sumatra or Straits of Malacca west of us;
#
# -Afternoon and evening thunderstorms caused by strong surface heating and by the sea breeze circulation that develops in the afternoon.
#
# Singapore’s climate station has been located at several different sites in the past 140 years. The station had been decommissioned at various points in the past due to changes to local land use in the site’s vicinity, and had to be relocated. Since 1984, the climate station has been located at **Changi**.
#
# There are other metrics of climate such as temperature, humidity, sun shine duration, wind speed, cloud cover etc. All the dataset used in the project comes from [data.gov.sg](data.gov.sg), as recorded at the Changi climate station

# %% [markdown]
# **Datasets provided**
# * [`rainfall-monthly-number-of-rain-days.csv`](../data/rainfall-monthly-number-of-rain-days.csv): Monthly number of rain days from 1982 to 2022. A day is considered to have “rained” if the total rainfall for that day is 0.2mm or more.
# * [`rainfall-monthly-total.csv`](../data/rainfall-monthly-total.csv): Monthly total rain recorded in mm(millimeters) from 1982 to 2022.
# * [`rainfall-monthly-highest-daily-total.csv`](../data/rainfall-monthly-highest-daily-total.csv): Monthly highest daily rain recorded in mm(millimeters) from 1982 to 2022. [Source: [Monthly Maximum Daily Rainfall](https://data.gov.sg/dataset/rainfall-monthly-maximum-daily-total)]
# * [`wet-bulb-temperature-hourly.csv`](../data/wet-bulb-temperature-hourly.csv): Hourly wet bulb temperature from 1982 to 2022. [Source: [Hourly wet buld temperature](https://data.gov.sg/dataset/wet-bulb-temperature-hourly)]
# * [`relative-humidity-monthly-mean.csv`](../data/relative-humidity-monthly-mean.csv): Monthly mean humidity from 1982 to 2022. [Source: [Relative Humidity](https://data.gov.sg/dataset/relative-humidity-monthly-mean)]
# * [`surface-air-temperature-monthly-mean.csv`](../data/surface-air-temperature-monthly-mean.csv): Monthly mean surface air temperature from 1982 to 2022. [Source: [Surface Air Temperature](https://data.gov.sg/dataset/surface-air-temperature-mean-daily-minimum)]
#
# **Other relevant datasets**
# * `dengue and others.xlsx`: Yearly number of notiable diseases from 1966 to 2021. Dengue/DHF was made a notifiable disease from August 1977. However it was administratively notifiable within government institutions since October 1966. [Source: https://tablebuilder.singstat.gov.sg/table/TS/M870081]
# * [`weekly-number-of-dengue-cases.csv`](../data/weekly-number-of-dengue-cases/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases.csv.csv): Weekly number of lab-confirmed dengue and dengue haemorrhagic fever cases from 2014 to 2018
#
# * Cluster dataset (in /data/sgcharts folder)

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Dengue fever has been a significant public health concern in Singapore, impacting the population's health and well-being. The country has experienced periodic outbreaks of dengue fever, with varying intensities and geographical spread. The disease is transmitted by the Aedes mosquito and can lead to severe symptoms, hospitalizations, and, in some cases, fatalities. Analyzing the trends of dengue fever cases is of utmost importance as it provides valuable insights into the patterns and dynamics of the disease. **Understanding the factors that contribute to the spread of dengue, including rainfall patterns, enables health authorities to implement targeted prevention and control measures.** By analyzing the trends, authorities can better allocate resources, enhance mosquito control efforts, and educate the public about effective preventive measures. This analysis plays a crucial role in mitigating the impact of dengue fever on the Singapore population and improving overall public health outcomes.

# %%
# Imports:
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# **Importing the rainfall data (monthly data)**

# %%
# Checking content and datatypes

rain_highest_daily = '../data/rainfall-monthly-highest-daily-total.csv'
high_df = pd.read_csv(rain_highest_daily)
display(high_df.head(5))
print(high_df.info())

rain_days = '../data/rainfall-monthly-number-of-rain-days.csv'
day_df = pd.read_csv(rain_days)
display(day_df.head(5))
print(day_df.info())

rain_monthly_total = '../data/rainfall-monthly-total.csv'
total_df = pd.read_csv(rain_monthly_total)
display(total_df.head(5))
print(day_df.info())
# Out:
#      month  maximum_rainfall_in_a_day
# 0  1982-01                       36.5
# 1  1982-02                        9.4
# 2  1982-03                       61.7
# 3  1982-04                       45.1
# 4  1982-05                       33.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      491 non-null    object
#  1   maximum_rainfall_in_a_day  491 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.8+ KB
# None
#      month  no_of_rainy_days
# 0  1982-01                10
# 1  1982-02                 5
# 2  1982-03                11
# 3  1982-04                14
# 4  1982-05                10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             488 non-null    object
#  1   no_of_rainy_days  488 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8+ KB
# None
#      month  total_rainfall
# 0  1982-01           107.1
# 1  1982-02            27.8
# 2  1982-03           160.8
# 3  1982-04           157.0
# 4  1982-05           102.2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             488 non-null    object
#  1   no_of_rainy_days  488 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.8+ KB
# None

# %%
# Standardising the date column

high_df['month'] =pd.to_datetime(  high_df['month'] )
day_df['month'] =pd.to_datetime(  day_df['month'] )
total_df['month'] =pd.to_datetime(  total_df['month'] )

# %%
# Merging rain datasets together

rain_df = pd.merge(high_df, day_df, on = 'month', how='outer')
rain_df = pd.merge(rain_df, total_df, on = 'month', how='outer')

rain_df = rain_df.set_index('month')
rain_df.index.names = ['date']

display(rain_df)
# Out:
#             maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall
# date
# 1982-01-01                       36.5              10.0           107.1
# 1982-02-01                        9.4               5.0            27.8
# 1982-03-01                       61.7              11.0           160.8
# 1982-04-01                       45.1              14.0           157.0
# 1982-05-01                       33.0              10.0           102.2
# ...                               ...               ...             ...
# 2022-07-01                       27.8              16.0           145.2
# 2022-08-01                       32.4              15.0           141.4
# 2022-09-01                       38.2               NaN             NaN
# 2022-10-01                       38.8               NaN             NaN
# 2022-11-01                       53.0               NaN             NaN
#
# [491 rows x 3 columns]

# %% [markdown]
# **Importing other weather-related datasets**

# %%
# Importing temperature data
wet_bulb_temperature_hourly = '../data/wet-bulb-temperature-hourly.csv'
bulb_temp_df = pd.read_csv(wet_bulb_temperature_hourly)

# Standardising the datetime column
bulb_temp_df['wbt_date'] =pd.to_datetime(  bulb_temp_df['wbt_date'] )
bulb_temp_df = bulb_temp_df.set_index('wbt_date')
bulb_temp_df = bulb_temp_df.rename(columns={'wet_bulb_temperature':'wbt'})
bulb_temp_df.index.names = ['date']

# Grouping by month as such granular data is not needed, and to standardise with weather data
bulb_temp_df = bulb_temp_df.groupby(bulb_temp_df.index.strftime('%Y-%m-01')).agg({'wbt': ['mean', 'min', 'max']})
bulb_temp_df.columns = ['_'.join(col) for col in bulb_temp_df.columns.values]
bulb_temp_df.index =pd.to_datetime( bulb_temp_df.index )
display(bulb_temp_df)
# Out:
#              wbt_mean  wbt_min  wbt_max
# date
# 1982-01-01  23.456048     21.3     25.6
# 1982-02-01  24.297619     22.4     26.8
# 1982-03-01  24.811559     22.4     27.4
# 1982-04-01  25.103750     22.2     27.6
# 1982-05-01  25.689651     22.7     28.1
# ...               ...      ...      ...
# 2022-07-01  25.439113     22.2     27.4
# 2022-08-01  25.072312     23.0     28.6
# 2022-09-01  24.833889     15.3     27.3
# 2022-10-01  24.688575     22.5     26.9
# 2022-11-01  24.674306     19.8     26.6
#
# [491 rows x 3 columns]

# %%
# Importing humidity data
humidity = '../data/relative-humidity-monthly-mean.csv'
humidity_df = pd.read_csv(humidity)
display(humidity_df.head(5))

# Importing surface air temperature data
sa_temp = '../data/surface-air-temperature-monthly-mean.csv'
sa_temp_df = pd.read_csv(sa_temp)
display(sa_temp_df.head(5))

# Merge and standardise date index
hs_df = pd.merge(humidity_df, sa_temp_df, on = 'month', how='outer')
hs_df['month'] =pd.to_datetime(  hs_df['month'] )
hs_df = hs_df.set_index('month')
hs_df.index.names = ['date']
print(hs_df.info())
display(hs_df.head(5))
# Out:
#      month  mean_rh
# 0  1982-01     81.2
# 1  1982-02     79.5
# 2  1982-03     82.3
# 3  1982-04     85.9
# 4  1982-05     83.2
#      month  mean_temp
# 0  1982-01       25.9
# 1  1982-02       27.1
# 2  1982-03       27.2
# 3  1982-04       27.0
# 4  1982-05       28.0
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 491 entries, 1982-01-01 to 2022-11-01
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   mean_rh    491 non-null    float64
#  1   mean_temp  491 non-null    float64
# dtypes: float64(2)
# memory usage: 11.5 KB
# None
#             mean_rh  mean_temp
# date
# 1982-01-01     81.2       25.9
# 1982-02-01     79.5       27.1
# 1982-03-01     82.3       27.2
# 1982-04-01     85.9       27.0
# 1982-05-01     83.2       28.0

# %%
# Merging all weather datasets together

weather_df = pd.concat([rain_df,bulb_temp_df], axis=1, join='outer')
weather_df = pd.concat([weather_df,hs_df], axis=1, join='outer')
display(weather_df)
# Out:
#             maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# date
# 1982-01-01                       36.5              10.0           107.1
# 1982-02-01                        9.4               5.0            27.8
# 1982-03-01                       61.7              11.0           160.8
# 1982-04-01                       45.1              14.0           157.0
# 1982-05-01                       33.0              10.0           102.2
# ...                               ...               ...             ...
# 2022-07-01                       27.8              16.0           145.2
# 2022-08-01                       32.4              15.0           141.4
# 2022-09-01                       38.2               NaN             NaN
# 2022-10-01                       38.8               NaN             NaN
# 2022-11-01                       53.0               NaN             NaN
#
#              wbt_mean  wbt_min  wbt_max  mean_rh  mean_temp
# date
# 1982-01-01  23.456048     21.3     25.6     81.2       25.9
# 1982-02-01  24.297619     22.4     26.8     79.5       27.1
# 1982-03-01  24.811559     22.4     27.4     82.3       27.2
# 1982-04-01  25.103750     22.2     27.6     85.9       27.0
# 1982-05-01  25.689651     22.7     28.1     83.2       28.0
# ...               ...      ...      ...      ...        ...
# 2022-07-01  25.439113     22.2     27.4     76.8       28.6
# 2022-08-01  25.072312     23.0     28.6     77.4       28.1
# 2022-09-01  24.833889     15.3     27.3     76.9       27.9
# 2022-10-01  24.688575     22.5     26.9     78.7       27.6
# 2022-11-01  24.674306     19.8     26.6     79.9       27.4
#
# [491 rows x 8 columns]

# %% [markdown]
# All weather data has been imported. Next, we will import the dengue datasets.

# %% [markdown]
# **Importing dengue dataset (Yearly data 1966-2021)**

# %%
#Importing and cleaning data

disease = '../data/dengue and others.xlsx'
disease_yearly_df = pd.read_excel(disease)
display(disease_yearly_df.head(5))

# Change table format into weather dataset format
disease_yearly_df = disease_yearly_df.T # Transpose table
disease_yearly_df.rename(disease_yearly_df.iloc[0,:], axis = 1, inplace = True) # Name the column titles properly
disease_yearly_df = disease_yearly_df.tail(-1) # Remove first row
disease_yearly_df.rename_axis('date', inplace = True) 
display(disease_yearly_df.head(5))
print(disease_yearly_df.info())

# Extract the useful data (dengue) and make sure the datatype is correct (integers) 
df_dengue_yearly = disease_yearly_df[['Dengue/DHF']]
df_dengue_yearly['Dengue/DHF'] = df_dengue_yearly['Dengue/DHF'].astype(int)

print(df_dengue_yearly.info())

df_dengue_yearly.reset_index(inplace=True)
df_dengue_yearly.set_index('date', inplace=True)
df_dengue_yearly = df_dengue_yearly.rename(columns={'Dengue/DHF': 'dengue_cases'} )

display(df_dengue_yearly.head())
# Out:
#        Data Series  2021   2020   2019  2018  2017   2016   2015   2014  \
# 0       Dengue/DHF  5261  35266  15979  3283  2767  13085  11294  18326
# 1          Malaria     2     13     33    35    39     31     47     62
# 2    Enteric Fever    20     40     85    59    81     70     76     77
# 3  Viral Hepatitis    99    141    161   193   217    193    207    194
# 4          Cholera     3      0      2     2     3      2      3      2
#
#     2013  ...  1975  1974  1973 1972 1971 1970 1969 1968 1967 1966
# 0  22170  ...    59   229  1255   12   19   32   60  158  355  162
# 1    111  ...   443   417   347  302  357  473  302  396  228  216
# 2    107  ...   513   301   154  167  224  158  237  134   93  124
# 3    202  ...    na    na    na   na   na   na   na   na   na   na
# 4      2  ...    10     8     1  114    0    1   10    6    0    0
#
# [5 rows x 57 columns]
#      Dengue/DHF Malaria Enteric Fever Viral Hepatitis Cholera Poliomyelitis  \
# date
# 2021       5261       2            20              99       3             0
# 2020      35266      13            40             141       0             0
# 2019      15979      33            85             161       2             0
# 2018       3283      35            59             193       2             0
# 2017       2767      39            81             217       3             0
#
#      Diphtheria Measles Legionellosis Nipah Virus Infection SARS Tuberculosis  \
# date
# 2021          0       0            14                     0    0         2314
# 2020          0      10            16                     0    0         2225
# 2019          0     152            23                     0    0         1978
# 2018          0      34            22                     0    0         2182
# 2017          1      70            19                     0    0         2191
#
#      Leprosy
# date
# 2021       9
# 2020       3
# 2019       4
# 2018       6
# 2017       6
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 2021 to 1966
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Dengue/DHF             56 non-null     object
#  1   Malaria                56 non-null     object
#  2   Enteric Fever          56 non-null     object
#  3   Viral Hepatitis        56 non-null     object
#  4   Cholera                56 non-null     object
#  5   Poliomyelitis          56 non-null     object
#  6   Diphtheria             56 non-null     object
#  7   Measles                56 non-null     object
#  8   Legionellosis          56 non-null     object
#  9   Nipah Virus Infection  56 non-null     object
#  10  SARS                   56 non-null     object
#  11  Tuberculosis           56 non-null     object
#  12  Leprosy                56 non-null     object
# dtypes: object(13)
# memory usage: 6.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 2021 to 1966
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dengue/DHF  56 non-null     int32
# dtypes: int32(1)
# memory usage: 672.0+ bytes
# None
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_8824\614558271.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dengue_yearly['Dengue/DHF'] = df_dengue_yearly['Dengue/DHF'].astype(int)
#       dengue_cases
# date
# 2021          5261
# 2020         35266
# 2019         15979
# 2018          3283
# 2017          2767

# %% [markdown]
# **Preparing yearly master dataset**

# %% [markdown]
# This dengue dataset covers the longest duration but it contains only a **yearly** total of dengue cases. Hence, I will aggregate the weather data as well for a yearly overview.

# %%
display(weather_df.head())

# Aggregating weather_df values
weather_df_year = weather_df.groupby(weather_df.index.year).agg({'maximum_rainfall_in_a_day': ['mean', 'min', 'max'], 
                                 'no_of_rainy_days': ['mean', 'min', 'max','sum'],
                                  'total_rainfall': ['mean', 'min', 'max','sum'],
                                  'wbt_mean': ['mean'],
                                  'wbt_min': ['min'],
                                  'wbt_max': ['max'],
                                  'mean_rh': ['mean'],
                                  'mean_temp': ['mean'],    
                                 })
weather_df_year.columns  = ['_'.join(col) for col in weather_df_year.columns.values]
display(weather_df_year.head())
# Out:
#             maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# date
# 1982-01-01                       36.5              10.0           107.1
# 1982-02-01                        9.4               5.0            27.8
# 1982-03-01                       61.7              11.0           160.8
# 1982-04-01                       45.1              14.0           157.0
# 1982-05-01                       33.0              10.0           102.2
#
#              wbt_mean  wbt_min  wbt_max  mean_rh  mean_temp
# date
# 1982-01-01  23.456048     21.3     25.6     81.2       25.9
# 1982-02-01  24.297619     22.4     26.8     79.5       27.1
# 1982-03-01  24.811559     22.4     27.4     82.3       27.2
# 1982-04-01  25.103750     22.2     27.6     85.9       27.0
# 1982-05-01  25.689651     22.7     28.1     83.2       28.0
#       maximum_rainfall_in_a_day_mean  maximum_rainfall_in_a_day_min  \
# date
# 1982                       38.150000                            9.4
# 1983                       57.891667                            5.1
# 1984                       66.758333                           22.5
# 1985                       32.016667                            9.9
# 1986                       59.933333                           23.0
#
#       maximum_rainfall_in_a_day_max  no_of_rainy_days_mean  \
# date
# 1982                          109.0              10.833333
# 1983                          181.8              12.083333
# 1984                          154.4              15.916667
# 1985                           86.8              15.083333
# 1986                          131.7              14.500000
#
#       no_of_rainy_days_min  no_of_rainy_days_max  no_of_rainy_days_sum  \
# date
# 1982                   5.0                  21.0                 130.0
# 1983                   2.0                  18.0                 145.0
# 1984                  11.0                  22.0                 191.0
# 1985                   7.0                  22.0                 181.0
# 1986                   2.0                  22.0                 174.0
#
#       total_rainfall_mean  total_rainfall_min  total_rainfall_max  \
# date
# 1982           131.808333                27.8               494.1
# 1983           166.141667                 5.6               370.6
# 1984           223.891667               102.7               470.4
# 1985           123.658333                37.0               340.1
# 1986           211.341667                26.7               396.0
#
#       total_rainfall_sum  wbt_mean_mean  wbt_min_min  wbt_max_max  \
# date
# 1982              1581.7      24.921417         21.3         28.1
# 1983              1993.7      25.234144         21.0         28.1
# 1984              2686.7      24.721475         21.0         27.5
# 1985              1483.9      24.857212         20.9         28.3
# 1986              2536.1      24.802940         21.3         27.8
#
#       mean_rh_mean  mean_temp_mean
# date
# 1982     81.966667       27.358333
# 1983     82.283333       27.666667
# 1984     84.616667       26.766667
# 1985     83.208333       27.116667
# 1986     82.866667       27.100000

# %%
# Merge dengue and dengue weather by year, and remove null data

df_year = pd.merge(weather_df_year, df_dengue_yearly, left_index = True, right_index=True, how = 'left')
print(df_year.info())
df_year.dropna(inplace=True)
print(df_year.info())

display(df_year.head())

df_year.rename(columns={'Dengue/DHF': 'dengue_cases', # can keep
                        'maximum_rainfall_in_a_day_mean': 'mean_monthly_max_rainfall',
                        'maximum_rainfall_in_a_day_min': 'min_monthly_max_rainfall',
                        'maximum_rainfall_in_a_day_max': 'max_monthly_max_rainfall', # can keep
                        'no_of_rainy_days_sum': 'total_rday', # can keep
                        'no_of_rainy_days_mean': 'mean_monthly_rday',
                        'no_of_rainy_days_min': 'min_monthly_rday',
                        'no_of_rainy_days_max': 'max_monthly_rday',
                        'total_rainfall_sum': 'total_rainfall', # can keep
                        'total_rainfall_mean': 'mean_monthly_rainfall',
                        'total_rainfall_min': 'min_monthly_rainfall',
                        'total_rainfall_max': 'max_monthly_rainfall',
                        'wbt_mean_mean': 'wbt_mean',
                        'wbt_max_max': 'wbt_max',
                        'mean_rh_mean': 'rh_mean',# can keep
                        'mean_temp_mean': 'temp_mean' # can keep
                        },
               inplace=True)
df_year = pd.concat((df_year['dengue_cases'],df_year.iloc[:,:-1]), axis =1)
display(df_year.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 1982 to 2022
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   maximum_rainfall_in_a_day_mean  41 non-null     float64
#  1   maximum_rainfall_in_a_day_min   41 non-null     float64
#  2   maximum_rainfall_in_a_day_max   41 non-null     float64
#  3   no_of_rainy_days_mean           41 non-null     float64
#  4   no_of_rainy_days_min            41 non-null     float64
#  5   no_of_rainy_days_max            41 non-null     float64
#  6   no_of_rainy_days_sum            41 non-null     float64
#  7   total_rainfall_mean             41 non-null     float64
#  8   total_rainfall_min              41 non-null     float64
#  9   total_rainfall_max              41 non-null     float64
#  10  total_rainfall_sum              41 non-null     float64
#  11  wbt_mean_mean                   41 non-null     float64
#  12  wbt_min_min                     41 non-null     float64
#  13  wbt_max_max                     41 non-null     float64
#  14  mean_rh_mean                    41 non-null     float64
#  15  mean_temp_mean                  41 non-null     float64
#  16  dengue_cases                    40 non-null     float64
# dtypes: float64(17)
# memory usage: 6.8 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 1982 to 2021
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   maximum_rainfall_in_a_day_mean  40 non-null     float64
#  1   maximum_rainfall_in_a_day_min   40 non-null     float64
#  2   maximum_rainfall_in_a_day_max   40 non-null     float64
#  3   no_of_rainy_days_mean           40 non-null     float64
#  4   no_of_rainy_days_min            40 non-null     float64
#  5   no_of_rainy_days_max            40 non-null     float64
#  6   no_of_rainy_days_sum            40 non-null     float64
#  7   total_rainfall_mean             40 non-null     float64
#  8   total_rainfall_min              40 non-null     float64
#  9   total_rainfall_max              40 non-null     float64
#  10  total_rainfall_sum              40 non-null     float64
#  11  wbt_mean_mean                   40 non-null     float64
#  12  wbt_min_min                     40 non-null     float64
#  13  wbt_max_max                     40 non-null     float64
#  14  mean_rh_mean                    40 non-null     float64
#  15  mean_temp_mean                  40 non-null     float64
#  16  dengue_cases                    40 non-null     float64
# dtypes: float64(17)
# memory usage: 5.6 KB
# None
#       maximum_rainfall_in_a_day_mean  maximum_rainfall_in_a_day_min  \
# date
# 1982                       38.150000                            9.4
# 1983                       57.891667                            5.1
# 1984                       66.758333                           22.5
# 1985                       32.016667                            9.9
# 1986                       59.933333                           23.0
#
#       maximum_rainfall_in_a_day_max  no_of_rainy_days_mean  \
# date
# 1982                          109.0              10.833333
# 1983                          181.8              12.083333
# 1984                          154.4              15.916667
# 1985                           86.8              15.083333
# 1986                          131.7              14.500000
#
#       no_of_rainy_days_min  no_of_rainy_days_max  no_of_rainy_days_sum  \
# date
# 1982                   5.0                  21.0                 130.0
# 1983                   2.0                  18.0                 145.0
# 1984                  11.0                  22.0                 191.0
# 1985                   7.0                  22.0                 181.0
# 1986                   2.0                  22.0                 174.0
#
#       total_rainfall_mean  total_rainfall_min  total_rainfall_max  \
# date
# 1982           131.808333                27.8               494.1
# 1983           166.141667                 5.6               370.6
# 1984           223.891667               102.7               470.4
# 1985           123.658333                37.0               340.1
# 1986           211.341667                26.7               396.0
#
#       total_rainfall_sum  wbt_mean_mean  wbt_min_min  wbt_max_max  \
# date
# 1982              1581.7      24.921417         21.3         28.1
# 1983              1993.7      25.234144         21.0         28.1
# 1984              2686.7      24.721475         21.0         27.5
# 1985              1483.9      24.857212         20.9         28.3
# 1986              2536.1      24.802940         21.3         27.8
#
#       mean_rh_mean  mean_temp_mean  dengue_cases
# date
# 1982     81.966667       27.358333         216.0
# 1983     82.283333       27.666667         205.0
# 1984     84.616667       26.766667          86.0
# 1985     83.208333       27.116667         126.0
# 1986     82.866667       27.100000         354.0
#       dengue_cases  mean_monthly_max_rainfall  min_monthly_max_rainfall  \
# date
# 1982         216.0                  38.150000                       9.4
# 1983         205.0                  57.891667                       5.1
# 1984          86.0                  66.758333                      22.5
# 1985         126.0                  32.016667                       9.9
# 1986         354.0                  59.933333                      23.0
#
#       max_monthly_max_rainfall  mean_monthly_rday  min_monthly_rday  \
# date
# 1982                     109.0          10.833333               5.0
# 1983                     181.8          12.083333               2.0
# 1984                     154.4          15.916667              11.0
# 1985                      86.8          15.083333               7.0
# 1986                     131.7          14.500000               2.0
#
#       max_monthly_rday  total_rday  mean_monthly_rainfall  \
# date
# 1982              21.0       130.0             131.808333
# 1983              18.0       145.0             166.141667
# 1984              22.0       191.0             223.891667
# 1985              22.0       181.0             123.658333
# 1986              22.0       174.0             211.341667
#
#       min_monthly_rainfall  max_monthly_rainfall  total_rainfall   wbt_mean  \
# date
# 1982                  27.8                 494.1          1581.7  24.921417
# 1983                   5.6                 370.6          1993.7  25.234144
# 1984                 102.7                 470.4          2686.7  24.721475
# 1985                  37.0                 340.1          1483.9  24.857212
# 1986                  26.7                 396.0          2536.1  24.802940
#
#       wbt_min_min  wbt_max    rh_mean  temp_mean
# date
# 1982         21.3     28.1  81.966667  27.358333
# 1983         21.0     28.1  82.283333  27.666667
# 1984         21.0     27.5  84.616667  26.766667
# 1985         20.9     28.3  83.208333  27.116667
# 1986         21.3     27.8  82.866667  27.100000

# %% [markdown]
# **Importing dengue dataset (Weekly data 2014-2018)**

# %%
#Importing and cleaning data

weekly_dengue = '../data/weekly-number-of-dengue-cases/weekly-number-of-dengue-and-dengue-haemorrhagic-fever-cases.csv'
weekly_dengue_df = pd.read_csv(weekly_dengue)
display(weekly_dengue_df)
print(weekly_dengue_df.info())
# Out:
#      year  eweek type_dengue  number
# 0    2014      1      Dengue   436.0
# 1    2014      1         DHF     1.0
# 2    2014      2      Dengue   479.0
# 3    2014      2         DHF     0.0
# 4    2014      3      Dengue   401.0
# ..    ...    ...         ...     ...
# 525  2018     51         DHF     1.0
# 526  2018     52      Dengue   160.0
# 527  2018     52         DHF     0.0
# 528  2018     53      Dengue     NaN
# 529  2018     53         DHF     NaN
#
# [530 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         530 non-null    int64
#  1   eweek        530 non-null    int64
#  2   type_dengue  530 non-null    object
#  3   number       522 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 16.7+ KB
# None

# %%
# Convert 'year' and 'eweek' columns to datetime
weekly_dengue_df['date'] = pd.to_datetime(weekly_dengue_df['year'].astype(str) + '-' + weekly_dengue_df['eweek'].astype(str) + '-1', format='%Y-%U-%w')

# Extract and groupby year and month
weekly_dengue_df['date'] = weekly_dengue_df['date'].dt.to_period('M')
monthly_dengue_df = weekly_dengue_df.groupby('date')['number'].sum().reset_index()

monthly_dengue_df['date'] = monthly_dengue_df['date'].dt.to_timestamp()
monthly_dengue_df.set_index('date', inplace=True)
monthly_dengue_df = monthly_dengue_df[:-1]

# Print the resulting dataframe
display(monthly_dengue_df.head())
# Out:
#             number
# date
# 2014-01-01  1653.0
# 2014-02-01  1071.0
# 2014-03-01  1057.0
# 2014-04-01  1002.0
# 2014-05-01  1231.0

# %% [markdown]
# **Preparing monthly master dataset**

# %% [markdown]
# This dengue dataset covers the weekly/monthly dengue cases (for a short duration of 2014-2018). Hence, I will merge with the monthly weather data for a monthly overview.

# %%
df_month = pd.merge(weather_df, monthly_dengue_df, left_index=True, right_index=True, how='outer')
display(df_month.head())

# Rename dengue cases
df_month.rename(columns={'number':'dengue'}, inplace=True)

# Remove rows where rain data is null
df_month = df_month[~df_month['total_rainfall'].isna()]

# Checking rows with dengue values to see if dataframes are outer-merged correctly
display(df_month[~df_month['dengue'].isna()].head())
# Out:
#             maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# date
# 1982-01-01                       36.5              10.0           107.1
# 1982-02-01                        9.4               5.0            27.8
# 1982-03-01                       61.7              11.0           160.8
# 1982-04-01                       45.1              14.0           157.0
# 1982-05-01                       33.0              10.0           102.2
#
#              wbt_mean  wbt_min  wbt_max  mean_rh  mean_temp  number
# date
# 1982-01-01  23.456048     21.3     25.6     81.2       25.9     NaN
# 1982-02-01  24.297619     22.4     26.8     79.5       27.1     NaN
# 1982-03-01  24.811559     22.4     27.4     82.3       27.2     NaN
# 1982-04-01  25.103750     22.2     27.6     85.9       27.0     NaN
# 1982-05-01  25.689651     22.7     28.1     83.2       28.0     NaN
#             maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# date
# 2014-01-01                       31.2               5.0            75.4
# 2014-02-01                        0.2               1.0             0.2
# 2014-03-01                       52.6               6.0            66.0
# 2014-04-01                       28.8              17.0           110.0
# 2014-05-01                       22.2              18.0           125.8
#
#              wbt_mean  wbt_min  wbt_max  mean_rh  mean_temp  dengue
# date
# 2014-01-01  23.391129     21.1     26.2     78.5       26.2  1653.0
# 2014-02-01  23.708333     21.1     25.9     74.5       27.2  1071.0
# 2014-03-01  24.544624     22.1     27.0     76.0       27.9  1057.0
# 2014-04-01  25.461806     22.4     27.0     80.0       28.2  1002.0
# 2014-05-01  25.811425     22.6     27.7     80.2       28.6  1231.0

# %% [markdown]
# **Importing dengue dataset (Cluster data 2015-2000)**

# %% [markdown]
# Please ignore this cluster dataset/ map sections as it may take more time
# ---

# %%
import os
import pandas as pd

# Create an empty master dataframe
master_df = pd.DataFrame(columns=['date', 'street_name', 'dengue_cases','latitude','longitude'])

# Specify the folder path containing the CSV files
folder_path = '../data/sgcharts/csv/'

# Iterate through the files in the folder
for filename in os.listdir(folder_path):
    
    print(filename)
    
    if filename.endswith('.csv'):
        
        # Extract the date from the filename
        date_str = filename[:6]  # Assuming the date is always the first 6 characters in the filename
        date = pd.to_datetime(date_str, format='%y%m%d').strftime('%Y-%m-%d')

        # Read the CSV file
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path, header=None)
        
        

        # Extract relevant columns and rename them
        df = df[[0, 1, 2, 3]]  # Select columns 0 and 1 (dengue_cases and street_name)
        df.columns = ['dengue_cases', 'street_name','latitude','longitude']  # Rename columns

        # Filter rows where street_name contains 'tampines'
        df_tampines = df[df['street_name'].str.contains('tampines', case=False)]

        # Create a new dataframe with date, street_name, and dengue_cases
        new_df = pd.DataFrame({
            'date': date,
            'street_name': 'Tampines',
            'dengue_cases': df_tampines['dengue_cases'],
            'latitude': df_tampines['latitude'],
            'longitude': df_tampines['longitude']
        })

        # Append the new dataframe to the master dataframe
        master_df = pd.concat([master_df,new_df], ignore_index=True)

# Print the master dataframe
print(master_df)
# Out:
# 150703-clusters.csv
# 150716-clusters.csv
# 150806-clusters.csv
# 150811-clusters.csv
# 150814-clusters.csv
# 150817-clusters.csv
# 150821-clusters.csv
# 150825-clusters.csv
# 150828-clusters.csv
# 150831-clusters.csv
# 150904-clusters.csv
# 150907-clusters.csv
# 150910-clusters.csv
# 150914-clusters.csv
# 150918-clusters.csv
# 150922-clusters.csv
# 150925-clusters.csv
# 150928-clusters.csv
# 151002-clusters.csv
# 151005-clusters.csv
# 151009-clusters.csv
# 151012-clusters.csv
# 151019-clusters.csv
# 151026-clusters.csv
# 151102-clusters.csv
# 151109-clusters.csv
# 151116-clusters.csv
# 151123-clusters.csv
# 151130-clusters.csv
# 151207-clusters.csv
# 151214-clusters.csv
# 151221-clusters.csv
# 151228-clusters.csv
# 160104-clusters.csv
# 160111-clusters.csv
# 160118-clusters.csv
# 160126-clusters.csv
# 160201-clusters.csv
# 160210-clusters.csv
# 160215-clusters.csv
# 160223-clusters.csv
# 160301-clusters.csv
# 160307-clusters.csv
# 160314-clusters.csv
# 160322-clusters.csv
# 160329-clusters.csv
# 160404-clusters.csv
# 160411-clusters.csv
# 160418-clusters.csv
# 160425-clusters.csv
# 160503-clusters.csv
# 160509-clusters.csv
# 160524-clusters.csv
# 160530-clusters.csv
# 160606-clusters.csv
# 160613-clusters.csv
# 160620-clusters.csv
# 160630-clusters.csv
# 160704-clusters.csv
# 160712-clusters.csv
# 160718-clusters.csv
# 160726-clusters.csv
# 160801-clusters.csv
# 160810-clusters.csv
# 160816-clusters.csv
# 160823-clusters.csv
# 160829-clusters.csv
# 160905-clusters.csv
# 160913-clusters.csv
# 160919-clusters.csv
# 160926-clusters.csv
# 161003-clusters.csv
# 161010-clusters.csv
# 161017-clusters.csv
# 161024-clusters.csv
# 161031-clusters.csv
# 161107-clusters.csv
# 161114-clusters.csv
# 161121-clusters.csv
# 161128-clusters.csv
# 161205-clusters.csv
# 161212-clusters.csv
# 161219-clusters.csv
# 161227-clusters.csv
# 170103-clusters.csv
# 170109-clusters.csv
# 170116-clusters.csv
# 170123-clusters.csv
# 170131-clusters.csv
# 170206-clusters.csv
# 170213-clusters.csv
# 170220-clusters.csv
# 170227-clusters.csv
# 170307-clusters.csv
# 170313-clusters.csv
# 170320-clusters.csv
# 170403-clusters.csv
# 170410-clusters.csv
# 170417-clusters.csv
# 170424-clusters.csv
# 170502-clusters.csv
# 170508-clusters.csv
# 170515-clusters.csv
# 170522-clusters.csv
# 170529-clusters.csv
# 170605-clusters.csv
# 170612-clusters.csv
# 170619-clusters.csv
# 170628-clusters.csv
# 170703-clusters.csv
# 170710-clusters.csv
# 170717-clusters.csv
# 170724-clusters.csv
# 170731-clusters.csv
# 170810-clusters.csv
# 170814-clusters.csv
# 170821-clusters.csv
# 170829-clusters.csv
# 170904-clusters.csv
# 170911-clusters.csv
# 170918-clusters.csv
# 170925-clusters.csv
# 171002-clusters.csv
# 171009-clusters.csv
# 171016-clusters.csv
# 171023-clusters.csv
# 171030-clusters.csv
# 171106-clusters.csv
# 171114-clusters.csv
# 171120-clusters.csv
# 171127-clusters.csv
# 171204-clusters.csv
# 171218-clusters.csv
# 171226-clusters.csv
# 180102-clusters.csv
# 180111-clusters.csv
# 180115-clusters.csv
# 180122-clusters.csv
# 180129-clusters.csv
# 180205-clusters.csv
# 180212-clusters.csv
# 180219-clusters.csv
# 180226-clusters.csv
# 180305-clusters.csv
# 180312-clusters.csv
# 180320-clusters.csv
# 180326-clusters.csv
# 180402-clusters.csv
# 180409-clusters.csv
# 180416-clusters.csv
# 180423-clusters.csv
# 180430-clusters.csv
# 180507-clusters.csv
# 180514-clusters.csv
# 180521-clusters.csv
# 180528-clusters.csv
# 180604-clusters.csv
# 180611-clusters.csv
# 180618-clusters.csv
# 180625-clusters.csv
# 180702-clusters.csv
# 180709-clusters.csv
# 180716-clusters.csv
# 180723-clusters.csv
# 180730-clusters.csv
# 180806-clusters.csv
# 180813-clusters.csv
# 180820-clusters.csv
# 180827-clusters.csv
# 180903-clusters.csv
# 180910-clusters.csv
# 180917-clusters.csv
# 180925-clusters.csv
# 181001-clusters.csv
# 181008-clusters.csv
# 181015-clusters.csv
# 181022-clusters.csv
# 181029-clusters.csv
# 181105-clusters.csv
# 181116-clusters.csv
# 181119-clusters.csv
# 181126-clusters.csv
# 181203-clusters.csv
# 181210-clusters.csv
# 181217-clusters.csv
# 181224-clusters.csv
# 181231-clusters.csv
# 190107-clusters.csv
# 190114-clusters.csv
# 190121-clusters.csv
# 190129-clusters.csv
# 190403-clusters.csv
# 190409-clusters.csv
# 190416-clusters.csv
# 190423-clusters.csv
# 190429-clusters.csv
# 190506-clusters.csv
# 190513-clusters.csv
# 190522-clusters.csv
# 190527-clusters.csv
# 190603-clusters.csv
# 190610-clusters.csv
# 190619-clusters.csv
# 190626-clusters.csv
# 190702-clusters.csv
# 190708-clusters.csv
# 190716-clusters.csv
# 190726-clusters.csv
# 190808-clusters.csv
# 190816-clusters.csv
# 190823-clusters.csv
# 190830-clusters.csv
# 190906-clusters.csv
# 190913-clusters.csv
# 190920-clusters.csv
# 190927-clusters.csv
# 191004-clusters.csv
# 191011-clusters.csv
# 191018-clusters.csv
# 191025-clusters.csv
# 191101-clusters.csv
# 191108-clusters.csv
# 191115-clusters.csv
# 191122-clusters.csv
# 191129-clusters.csv
# 191206-clusters.csv
# 191213-clusters.csv
# 191220-clusters.csv
# 191227-clusters.csv
# 200103-clusters.csv
# 200110-clusters.csv
# 200117-clusters.csv
# 200124-clusters.csv
# 200131-clusters.csv
# 200207-clusters.csv
# 200214-clusters.csv
# 200221-clusters.csv
# 200228-clusters.csv
# 200306-clusters.csv
# 200313-clusters.csv
# 200320-clusters.csv
# 200327-clusters.csv
# 200403-clusters.csv
# 200409-clusters.csv
# 200417-clusters.csv
# 200424-clusters.csv
# 200430-clusters.csv
# 200508-clusters.csv
# 200515-clusters.csv
# 200522-clusters.csv
# 200529-clusters.csv
# 200605-clusters.csv
# 200703-clusters.csv
# 200807-clusters.csv
# 200918-clusters.csv
# 201106-clusters.csv
#             date street_name dengue_cases  latitude   longitude
# 0     2015-07-03    Tampines            1  1.355875  103.958032
# 1     2015-07-03    Tampines            1  1.354327  103.960943
# 2     2015-07-03    Tampines            1  1.355777  103.960731
# 3     2015-07-03    Tampines            1  1.349591  103.956788
# 4     2015-07-03    Tampines            1  1.356391  103.947332
# ...          ...         ...          ...       ...         ...
# 2605  2020-11-06    Tampines            1  1.364231  103.954394
# 2606  2020-11-06    Tampines            1   1.35966  103.937074
# 2607  2020-11-06    Tampines            1  1.359482  103.936586
# 2608  2020-11-06    Tampines            1  1.351145  103.936991
# 2609  2020-11-06    Tampines            1  1.351754  103.938303
#
# [2610 rows x 5 columns]

# %%
master_df.info()

master_df['date'] = pd.to_datetime(master_df['date'])
master_df['dengue_cases'] = master_df['dengue_cases'].astype(int)
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2610 entries, 0 to 2609
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2610 non-null   object
#  1   street_name   2610 non-null   object
#  2   dengue_cases  2610 non-null   object
#  3   latitude      2610 non-null   object
#  4   longitude     2610 non-null   object
# dtypes: object(5)
# memory usage: 102.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2610 entries, 0 to 2609
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2610 non-null   datetime64[ns]
#  1   street_name   2610 non-null   object
#  2   dengue_cases  2610 non-null   int32
#  3   latitude      2610 non-null   object
#  4   longitude     2610 non-null   object
# dtypes: datetime64[ns](1), int32(1), object(3)
# memory usage: 91.9+ KB

# %%
display(master_df.head(10) )
display(master_df.groupby([master_df.date.dt.year,master_df.date.dt.month])[['dengue_cases']].sum())
# Out:
#         date street_name  dengue_cases  latitude   longitude
# 0 2015-07-03    Tampines             1  1.355875  103.958032
# 1 2015-07-03    Tampines             1  1.354327  103.960943
# 2 2015-07-03    Tampines             1  1.355777  103.960731
# 3 2015-07-03    Tampines             1  1.349591  103.956788
# 4 2015-07-03    Tampines             1  1.356391  103.947332
# 5 2015-07-03    Tampines             1  1.355845  103.948161
# 6 2015-07-03    Tampines             1  1.359479  103.946873
# 7 2015-07-03    Tampines             1  1.357849  103.946666
# 8 2015-07-03    Tampines             3  1.352429  103.955728
# 9 2015-07-03    Tampines             1  1.360462  103.957117
#            dengue_cases
# date date
# 2015 7               21
#      8               29
#      9               35
#      10             187
#      11             208
#      12             518
# 2016 1              997
#      2              990
#      3              260
#      4              243
#      5              191
#      6               68
#      7              135
#      8              282
#      9               33
#      10               6
#      11               8
#      12               5
# 2017 1               70
#      2               78
#      3               14
#      4                2
#      6                6
#      11               7
#      12               6
# 2018 1               40
#      2               43
#      3               18
#      4                2
#      5                6
#      6               34
#      7               10
#      8               18
#      9                3
#      12               3
# 2019 1               21
#      4                2
#      5                4
#      6               69
#      7              149
#      8              101
#      9              155
#      10             130
#      11              34
#      12               2
# 2020 1                5
#      2               14
#      3               32
#      4               99
#      5              388
#      6              130
#      7              193
#      8              261
#      9              132
#      11             216

# %%
master_df = master_df.groupby([master_df.date.dt.year,master_df.date.dt.month]).agg({'dengue_cases': ['sum'], 'latitude': 'mean', 'longitude':'mean'})

# %%
display(master_df.head())
# Out:
#           dengue_cases  latitude   longitude
#                    sum      mean        mean
# date date
# 2015 7              21  1.354823  103.953416
#      8              29  1.348694  103.942639
#      9              35  1.352025  103.948262
#      10            187  1.350594  103.945707
#      11            208  1.349904  103.944069

# %%
import folium
from folium.plugins import HeatMap

# Create a folium map centered on Singapore
map_heat = folium.Map(location=[1.3521, 103.8198], zoom_start=12)

# Convert the master_df to a format expected by HeatMap (list of lat-lon coordinates)
heatmap_data = master_df[['latitude', 'longitude', 'dengue_cases']].values.tolist()

# Create the heatmap layer using HeatMap plugin
heat_layer = HeatMap(heatmap_data, radius=15)
map_heat.add_child(heat_layer)

# Display the map
map_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b35ba7622d3ec86583ec37ba661df8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b35ba7622d3ec86583ec37ba661df8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b35ba7622d3ec86583ec37ba661df8f = L.map(
#                 &quot;map_8b35ba7622d3ec86583ec37ba661df8f&quot;,
#                 {
#                     center: [1.3521, 103.8198],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50683b51a57d3efe8aa8c1f5c68bf823 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8b35ba7622d3ec86583ec37ba661df8f);
#
#
#             var heat_map_c88cc2397a00a44471ef569c18d449dc = L.heatLayer(
#                 [[1.3548226375000003, 103.95341573124999, 21.0], [1.3486936476190479, 103.94263852857145, 29.0], [1.3520250718749998, 103.948262075, 35.0], [1.3505944152941176, 103.94570680235294, 187.0], [1.3499041730769228, 103.94406925641023, 208.0], [1.3476986777777782, 103.93889918080804, 518.0], [1.3497371399122804, 103.93925150087712, 997.0], [1.3500184579365082, 103.93710050515865, 990.0], [1.355013651145038, 103.93926372824426, 260.0], [1.356755416483516, 103.94408062417584, 243.0], [1.3554595641975313, 103.9441214901235, 191.0], [1.3520554212765958, 103.93540171063827, 68.0], [1.351121606944445, 103.93179834166665, 135.0], [1.3512324933823523, 103.93370256691183, 282.0], [1.3492053000000002, 103.95114476842103, 33.0], [1.3527641499999998, 103.93732449999999, 6.0], [1.3554618857142857, 103.9485915, 8.0], [1.3475621, 103.94475539999999, 5.0], [1.3490317428571428, 103.94525387142858, 70.0], [1.3507393697674421, 103.94716647674417, 78.0], [1.3555987, 103.94767600000003, 14.0], [1.351576, 103.961102, 2.0], [1.35665875, 103.94638228333332, 6.0], [1.35307625, 103.94252098333332, 7.0], [1.357520825, 103.950959825, 6.0], [1.3570853035714285, 103.95127507142855, 40.0], [1.3582737620689653, 103.95182058275863, 43.0], [1.349284275, 103.9469454125, 18.0], [1.3506936999999999, 103.9459177, 2.0], [1.3496967333333334, 103.945552, 6.0], [1.34986095, 103.94528958749999, 34.0], [1.3550923714285716, 103.94993044285715, 10.0], [1.3583021785714284, 103.95195619285714, 18.0], [1.3602056333333332, 103.95437673333333, 3.0], [1.3580907, 103.95119643333332, 3.0], [1.3527779714285713, 103.94931678571426, 21.0], [1.3624505, 103.95800750000001, 2.0], [1.359277, 103.9456565, 4.0], [1.3584031229166669, 103.94199843125, 69.0], [1.3552774080808079, 103.94552811717173, 149.0], [1.3533548600000003, 103.94760077222222, 101.0], [1.353661187179487, 103.94929358589746, 155.0], [1.354876449090909, 103.95164200727271, 130.0], [1.35237432, 103.94673191666665, 34.0], [1.3578505, 103.9318525, 2.0], [1.3509980000000001, 103.93926922, 5.0], [1.35409372, 103.92601548999998, 14.0], [1.3611151687499998, 103.9206618125, 32.0], [1.357299532727273, 103.93934702363636, 99.0], [1.3558313897435896, 103.95647444188032, 388.0], [1.3547757400000002, 103.95714497142858, 130.0], [1.3544539297297302, 103.95108652432434, 193.0], [1.3543328605042013, 103.9498087, 261.0], [1.3562297794117646, 103.94750249705884, 132.0], [1.352043457627119, 103.94605855593225, 216.0]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 15}
#             ).addTo(map_8b35ba7622d3ec86583ec37ba661df8f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
from folium.plugins import HeatMap
import time

# Specify the starting year and month
start_year = 2021
start_month = 1

# Specify the maximum year and month
max_year = 2023
max_month = 5

# Iterate over the years and months
for year in range(start_year, max_year + 1):
    # Determine the start month for the current year
    if year == start_year:
        start_month_iter = start_month
    else:
        start_month_iter = 1
    
    # Iterate over the months for the current year
    for month in range(start_month_iter, max_month + 1):
        # Filter the master_df for the current year and month
        filtered_data = master_df[(master_df['date'].dt.year == year) & (master_df['date'].dt.month == month)]
        
        # Convert the filtered_data to a format expected by HeatMap (list of lat-lon coordinates)
        heatmap_data = filtered_data[['latitude', 'longitude', 'dengue_cases']].values.tolist()
        
        # Create a folium map centered on Singapore
        map_heat = folium.Map(location=[1.3521, 103.8198], zoom_start=12)
        
        # Create the heatmap layer using the HeatMap plugin
        heat_layer = HeatMap(heatmap_data, radius=15)
        map_heat.add_child(heat_layer)
        
        # Display the map
        display(map_heat)
        
        # Pause for a certain duration (e.g., 1 second) before updating to the next month
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 14>()
#      21 # Iterate over the months for the current year
#      22 for month in range(start_month_iter, max_month + 1):
#      23     # Filter the master_df for the current year and month
# ---> 24     filtered_data = master_df[(master_df['date'].dt.year == year) & (master_df['date'].dt.month == month)]
#      26     # Convert the filtered_data to a format expected by HeatMap (list of lat-lon coordinates)
#      27     heatmap_data = filtered_data[['latitude', 'longitude', 'dengue_cases']].values.tolist()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3504, in DataFrame.__getitem__(self, key)
#    3502 if is_single_key:
#    3503     if self.columns.nlevels > 1:
# -> 3504         return self._getitem_multilevel(key)
#    3505     indexer = self.columns.get_loc(key)
#    3506     if is_integer(indexer):
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3555, in DataFrame._getitem_multilevel(self, key)
#    3553 def _getitem_multilevel(self, key):
#    3554     # self.columns is a MultiIndex
# -> 3555     loc = self.columns.get_loc(key)
#    3556     if isinstance(loc, (slice, np.ndarray)):
#    3557         new_columns = self.columns[loc]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py:2869, in MultiIndex.get_loc(self, key, method)
#    2866     return mask
#    2868 if not isinstance(key, tuple):
# -> 2869     loc = self._get_level_indexer(key, level=0)
#    2870     return _maybe_to_slice(loc)
#    2872 keylen = len(key)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py:3222, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3218         return slice(i, j, step)
#    3220 else:
# -> 3222     idx = self._get_loc_single_level_index(level_index, key)
#    3224     if level > 0 or self._lexsort_depth == 0:
#    3225         # Desired level is not sorted
#    3226         if isinstance(idx, slice):
#    3227             # test_get_loc_partial_timestamp_multiindex
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py:2802, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2800     return -1
#    2801 else:
# -> 2802     return level_index.get_loc(key)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'date'

# %% [markdown]
# **Save the cleaned and merged dataframes as csv files**

# %%
# Use (3) monthly master dataset where possible as it contains monthly dengue cases data (but limited to a few years only. 
# (1) has yearly dengue data from another source, but doesnt show monthly details 

# (1) Saving yearly dengue dataset
os.makedirs('../data/output', exist_ok=True)  
df_year.to_csv('../data/output/df_dengue_yearly.csv') 

# (2) Saving  yearly master dataset 
os.makedirs('../data/output', exist_ok=True)  
df_year.to_csv('../data/output/yearly_df.csv')  

# (3) Saving monthly master dataset
os.makedirs('../data/output', exist_ok=True)  
df_year.to_csv('../data/output/monthly_df.csv')

# %% [markdown]
# # New Graphs

# %%
import seaborn as sns
sns.set(style='whitegrid')

# %%
df_dengue_yearly = pd.read_csv('../data/output/df_dengue_yearly.csv')
monthly_df = pd.read_csv('../data/output/monthly_df.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataframe is named 'df'
# Make sure to replace 'df' with the actual name of your dataframe

# Create a list of all column names excluding 'Dengue/DHF'
column_names = df_year.columns.tolist()
column_names.remove('Dengue/DHF')

# Iterate over each column and plot the line graph
for column in column_names:
    plt.figure()  # Create a new figure for each plot

    # Plot 'Dengue/DHF' on the left y-axis
    fig, ax1 = plt.subplots(figsize=(20,8))
    ax1.plot(df_year.index, df_year['Dengue/DHF'], label='Dengue/DHF', color='blue')
    ax1.set_xlabel('Year')
    ax1.set_ylabel('Dengue/DHF', color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')
    ax1.legend(loc='upper left')

    # Plot the current column on the right y-axis
    ax2 = ax1.twinx()
    ax2.plot(df_year.index, df_year[column], label=column, color='green')
    ax2.set_ylabel(column, color='green')
    ax2.tick_params(axis='y', labelcolor='green')
    ax2.legend(loc='upper right')

    plt.title(f'Line Graph: Dengue/DHF vs {column}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 9>()
#       4 # Assuming your dataframe is named 'df'
#       5 # Make sure to replace 'df' with the actual name of your dataframe
#       6
#       7 # Create a list of all column names excluding 'Dengue/DHF'
#       8 column_names = df_year.columns.tolist()
# ----> 9 column_names.remove('Dengue/DHF')
#      11 # Iterate over each column and plot the line graph
#      12 for column in column_names:
#
# ValueError: list.remove(x): x not in list

# %%
import matplotlib.pyplot as plt
import pandas as pd



# Get the column names excluding 'Dengue/DHF'
column_names = df_year.columns.tolist()
column_names.remove('Dengue/DHF')

# Plot each column with 'Dengue/DHF' in separate subplots
for column_name in column_names:
    fig, ax1 = plt.subplots()

    # Plot 'Dengue/DHF' on the left y-axis
    ax1.plot(df_year['Dengue/DHF'], color='blue', label='Dengue/DHF')
    ax1.set_xlabel('Year')
    ax1.set_ylabel('Dengue/DHF', color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')

    # Create a secondary y-axis for the other column
    ax2 = ax1.twinx()

    # Plot the current column on the right y-axis
    ax2.plot(df_year[column_name], color='red', label=column_name)
    ax2.set_ylabel(column_name, color='red')
    ax2.tick_params(axis='y', labelcolor='red')

    # Add a legend
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    lines = lines1 + lines2
    labels = labels1 + labels2
    ax1.legend(lines, labels, loc='upper left')

    # Adjust the layout to prevent overlap of the y-axis labels
    fig.tight_layout()

    # Display the plot
    plt.title(f'{column_name} vs Dengue/DHF')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 8>()
#       6 # Get the column names excluding 'Dengue/DHF'
#       7 column_names = df_year.columns.tolist()
# ----> 8 column_names.remove('Dengue/DHF')
#      10 # Plot each column with 'Dengue/DHF' in separate subplots
#      11 for column_name in column_names:
#
# ValueError: list.remove(x): x not in list

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your DataFrame is named 'df'
# Set the 'date' column as the index

# Get the column names excluding 'Dengue/DHF'
column_names = df_year.columns.tolist()
column_names.remove('Dengue/DHF')

# Iterate over each column and create separate plots
for column_name in column_names:
    # Create a new figure and axes
    fig, ax1 = plt.subplots()

    # Plot 'Dengue/DHF' on the left y-axis
    sns.lineplot(data=df_year, x=df_year.index, y='Dengue/DHF', ax=ax1, color='blue', label='Dengue/DHF')

    # Set labels and colors for the left y-axis
    ax1.set_xlabel('Year')
    ax1.set_ylabel('Dengue/DHF', color='blue')

    # Create a secondary y-axis for the other column
    ax2 = ax1.twinx()

    # Plot the current column on the right y-axis
    sns.lineplot(data=df_year, x=df_year.index, y=column_name, ax=ax2, color='red', label=column_name)

    # Set labels and colors for the right y-axis
    ax2.set_ylabel(column_name, color='red')

    # Adjust the layout
    fig.tight_layout()

    # Show the plot
    plt.title(f'{column_name} vs Dengue/DHF')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 10>()
#       5 # Assuming your DataFrame is named 'df'
#       6 # Set the 'date' column as the index
#       7
#       8 # Get the column names excluding 'Dengue/DHF'
#       9 column_names = df_year.columns.tolist()
# ---> 10 column_names.remove('Dengue/DHF')
#      12 # Iterate over each column and create separate plots
#      13 for column_name in column_names:
#      14     # Create a new figure and axes
#
# ValueError: list.remove(x): x not in list

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd



# Get the column names excluding 'Dengue/DHF'
column_names = df_year.columns.tolist()
column_names.remove('Dengue/DHF')

# Set seaborn style
sns.set(style='darkgrid')

# Iterate over each column and create separate plots
for column_name in column_names:
    # Create a new figure and axes
    fig, ax1 = plt.subplots()

    # Plot 'Dengue/DHF' on the left y-axis
    sns.lineplot(data=df_year, x=df_year.index, y='Dengue/DHF', ax=ax1, color='blue', label='Dengue/DHF')

    # Set labels and colors for the left y-axis
    ax1.set_xlabel('Year')
    ax1.set_ylabel('Dengue/DHF', color='blue')

    # Create a secondary y-axis for the other column
    ax2 = ax1.twinx()

    # Plot the current column on the right y-axis
    sns.lineplot(data=df_year, x=df_year.index, y=column_name, ax=ax2, color='purple', label=column_name)

    # Set labels and colors for the right y-axis
    ax2.set_ylabel(column_name, color='purple')

    # Remove spines
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    ax2.spines['top'].set_visible(False)
    ax2.spines['left'].set_visible(False)

    # Adjust the layout
    fig.tight_layout()

    # Show the plot
    plt.title(f'{column_name} vs Dengue/DHF')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 9>()
#       7 # Get the column names excluding 'Dengue/DHF'
#       8 column_names = df_year.columns.tolist()
# ----> 9 column_names.remove('Dengue/DHF')
#      11 # Set seaborn style
#      12 sns.set(style='darkgrid')
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |mean_max_rain|float|df_year|Mean of the highest daily rainfall in each month in mm|
# |min_max_rain|float|df_year|Minimum of the highest daily rainfall in each month in mm|
# |max_max_rain|float|df_year|Highest daily rainfall in each month in mm|
# |total_rday_mean|float|df_year|Mean of monthly number of rain days|
# |total_rday_min|float|df_year|Lowest monthly number of rain days|
# |total_rday_max|float|df_year|Highest monthly number of rain days|
# |total_rday_sum|float|df_year|Total number of rainy days in a year|
# |total_rain_mean|float|df_year|Mean of total monthly rainfall in mm|
# |total_rain_min|float|df_year|Minimum of total monthly rainfall in mm|
# |total_rain_max|float|df_year|Maximum of total monthly rainfall in mm|
# |total_rain_sum|float|df_year|Total rainfall in a year in mm|
# |wbt_mean|float|df_year|mean-monthly-wet-bulb-temperature|
# |wbt_min_min|float|df_year|min-monthly-wet-bulb-temperature|
# |wbt_max|float|df_year|max-monthly-wet-bulb-temperature|
# |rh_mean|float|df_year|Mean relative humidity|
# |temp_mean|float|df_year|Mean surface air temperature|
# |dengue_case|float|df_year|Total number of dengue cases in a year|
# |---|---|---|---|
# |maximum_rainfall_in_a_day|float|df_month|Highest daily rainfall in each month|
# |no_of_rainy_days|float|df_month|Monthly number of rain days|
# |total_rainfall|float|df_month|Total monthly rainfall in mm|
# |wbt_mean|float|df_month|Mean monthly-wet-bulb-temperature|
# |wbt_min|float|df_month|Mininum monthly-wet-bulb-temperature|
# |wbt_max|float|df_month|Maximum monthly-wet-bulb-temperature|
# |mean_rh|float|df_month|Mean relative humidity|
# |mean_temp|float|df_month|Mean surface air temperature|
# |dengue|float|df_month|Total number of dengue cases in a month|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Possible trends to invstigate / GUIDELINES:
#
#         - Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest total rainfall in the date range of analysis?
#         - Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?
#         - Which year have the highest and lowest number of rainy days in the date range of analysis?
#         - Are there any outliers months in the dataset?

# %% [markdown]
# **1. Summary Statistics**

# %%
df_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 488 entries, 1982-01-01 to 2022-08-01
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   maximum_rainfall_in_a_day  488 non-null    float64
#  1   no_of_rainy_days           488 non-null    float64
#  2   total_rainfall             488 non-null    float64
#  3   wbt_mean                   488 non-null    float64
#  4   wbt_min                    488 non-null    float64
#  5   wbt_max                    488 non-null    float64
#  6   mean_rh                    488 non-null    float64
#  7   mean_temp                  488 non-null    float64
#  8   dengue                     60 non-null     float64
# dtypes: float64(9)
# memory usage: 38.1 KB

# %%
df_month.describe()
# Out:
#        maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# count                 488.000000        488.000000      488.000000
# mean                   52.332172         14.061475      177.163730
# std                    35.746423          4.947394      113.916029
# min                     0.200000          1.000000        0.200000
# 25%                    30.675000         11.000000       93.850000
# 50%                    43.900000         14.000000      159.450000
# 75%                    63.050000         18.000000      238.075000
# max                   216.200000         27.000000      765.900000
#
#          wbt_mean     wbt_min     wbt_max     mean_rh   mean_temp       dengue
# count  488.000000  488.000000  488.000000  488.000000  488.000000    60.000000
# mean    25.258198   22.406352   27.472746   82.247541   27.678893   812.583333
# std      0.593979    0.663062    0.599431    3.413940    0.802195   683.323540
# min     23.391129   20.100000   25.600000   72.000000   25.400000   149.000000
# 25%     24.925235   22.000000   27.100000   80.000000   27.100000   266.750000
# 50%     25.290793   22.500000   27.500000   82.650000   27.700000   637.500000
# 75%     25.645094   22.900000   27.900000   84.700000   28.300000  1090.250000
# max     26.913978   24.500000   29.300000   90.700000   29.500000  3090.000000

# %% [markdown]
# **Observation**
# 1. There is observably a high standard deviation for the number of dengue cases
# 2. The wbt_max, wbt_mean and mean_temp seems to have the lowest standard deviations

# %% [markdown]
# **3. Investigate trends in the data**

# %% [markdown]
# **Which month have the highest and lowest total rainfall in 1990, 2000, 2010 and 2020?**

# %%
# Filter the DataFrame for the specific years (1990, 2000, 2010, 2020)
selected_years = [1990, 2000, 2010, 2020]
df_selected_years = df_month[df_month.index.year.isin(selected_years)]

# Group the total rainfall by month and year, and calculate the sum
total_rainfall_by_month_year = df_selected_years['total_rainfall'].groupby([df_selected_years.index.month, df_selected_years.index.year]).sum()

# Reshape the data to have each year as a separate column
total_rainfall_by_month_year = total_rainfall_by_month_year.unstack()

# Create a grouped bar plot
total_rainfall_by_month_year.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Month')
plt.ylabel('Total Rainfall')
plt.title('Total Rainfall by Month for Selected Years')

plt.legend(title='Year')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the DataFrame for the specific years (1990, 2000, 2010, 2020)
selected_years = [1990, 2000, 2010, 2020]
df_selected_years = df_month[df_month.index.year.isin(selected_years)]

# Group the total rainfall by month and year, and calculate the sum
total_rainfall_by_month_year = df_selected_years['total_rainfall'].groupby([df_selected_years.index.month, df_selected_years.index.year]).sum()

# Reshape the data to have each year as a separate column
total_rainfall_by_month_year = total_rainfall_by_month_year.unstack()

# Create a line plot
sns.lineplot(data=total_rainfall_by_month_year)

plt.xlabel('Month')
plt.ylabel('Total Rainfall')
plt.title('Total Rainfall by Month for Selected Years')

plt.legend(title='Year')

plt.show()

# %%
# Reset the index of the DataFrame
df_month_r = df_month.reset_index()

# Extract the month from the 'date' column
df_month_r['month'] = pd.to_datetime(df_month_r['date']).dt.month

# Create a line plot with error bars
sns.lineplot(data=df_month_r, x='month', y='total_rainfall', ci='sd')

plt.xlabel('Month')
plt.ylabel('Total Rainfall')
plt.title('Total Rainfall by Month')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the DataFrame for the specific years (1990, 2000, 2010, 2020)
selected_years = [1990, 2000, 2010, 2020]
df_selected_years = df_month[df_month.index.year.isin(selected_years)]

# Reset the index of the DataFrame
df_selected_years.reset_index(inplace=True)

# Extract the month from the 'date' column
df_selected_years['month'] = pd.to_datetime(df_selected_years['date']).dt.month

# Create a line plot for each year
sns.lineplot(data=df_selected_years, x='month', y='total_rainfall', hue=df_selected_years['date'].dt.year, palette='colorblind')

plt.xlabel('Month')
plt.ylabel('Total Rainfall')
plt.title('Total Rainfall by Month for Selected Years')

plt.legend(title='Year')

plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_8824\3289494783.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected_years['month'] = pd.to_datetime(df_selected_years['date']).dt.month

# %%
years = [1990, 2000, 2010, 2020]

for year in years:
    rainfall_year = df_month.loc[df_month.index.year == year, 'total_rainfall']
    max_rainfall_month = rainfall_year.idxmax().strftime('%B')
    min_rainfall_month = rainfall_year.idxmin().strftime('%B')
    print(f"For the year {year}:")
    print(f"Highest total rainfall month: {max_rainfall_month}")
    print(f"Lowest total rainfall month: {min_rainfall_month}")
    print()
# Out:
# For the year 1990:
# Highest total rainfall month: September
# Lowest total rainfall month: February
#
# For the year 2000:
# Highest total rainfall month: November
# Lowest total rainfall month: September
#
# For the year 2010:
# Highest total rainfall month: July
# Lowest total rainfall month: February
#
# For the year 2020:
# Highest total rainfall month: May
# Lowest total rainfall month: February

# %% [markdown]
# Findings:
# - The month with the highest total rainfall (Heaviest rain) had gotten earlier as the years progress.
# - The month with the lowest rainfall is February most of the time.

# %% [markdown]
# **Which year have the highest and lowest total rainfall in the date range of analysis?**

# %%
df_month['total_rainfall']
# Out:
# date
# 1982-01-01    107.1
# 1982-02-01     27.8
# 1982-03-01    160.8
# 1982-04-01    157.0
# 1982-05-01    102.2
#               ...
# 2022-04-01    239.6
# 2022-05-01    102.0
# 2022-06-01    211.8
# 2022-07-01    145.2
# 2022-08-01    141.4
# Name: total_rainfall, Length: 488, dtype: float64

# %%
# Group the total rainfall by year and calculate the sum
total_rainfall_by_year = df_month['total_rainfall'].groupby(df_month.index.year).sum()

# Create a wider figure and adjust the size as per your preference
plt.figure(figsize=(15, 6))

# Create a line plot using seaborn
sns.lineplot(x=total_rainfall_by_year.index, y=total_rainfall_by_year.values)

plt.xlabel('Year', fontsize=20)
plt.ylabel('Total Rainfall (in mm)', fontsize=20)
plt.title('Cyclical Trend of Total Rainfall over the Years', fontsize=25)

# Rotate the x-axis labels by 45 degrees
plt.xticks(rotation=45)

# Specify x-axis ticks and labels for every year
plt.xticks(total_rainfall_by_year.index)

# Find the highest peaks in the years 2021 and 2007
highest_peaks = total_rainfall_by_year.nlargest(2)

# Draw dotted guiding lines up to the highest peaks in 2021 and 2007
for year in highest_peaks.index:
    plt.axvline(x=year, color='r', linestyle='--')

plt.show()

# %%
max_rainfall_year = df_month['total_rainfall'].groupby(df_month.index.year).sum().idxmax()
min_rainfall_year = df_month['total_rainfall'].groupby(df_month.index.year).sum().idxmin()

print(f"Highest total rainfall year in the date range: {max_rainfall_year}")
print(f"Lowest total rainfall year in the date range: {min_rainfall_year}")
# Out:
# Highest total rainfall year in the date range: 2007
# Lowest total rainfall year in the date range: 1997

# %%
df_month.head()
# Out:
#             maximum_rainfall_in_a_day  no_of_rainy_days  total_rainfall  \
# date
# 1982-01-01                       36.5              10.0           107.1
# 1982-02-01                        9.4               5.0            27.8
# 1982-03-01                       61.7              11.0           160.8
# 1982-04-01                       45.1              14.0           157.0
# 1982-05-01                       33.0              10.0           102.2
#
#              wbt_mean  wbt_min  wbt_max  mean_rh  mean_temp  dengue
# date
# 1982-01-01  23.456048     21.3     25.6     81.2       25.9     NaN
# 1982-02-01  24.297619     22.4     26.8     79.5       27.1     NaN
# 1982-03-01  24.811559     22.4     27.4     82.3       27.2     NaN
# 1982-04-01  25.103750     22.2     27.6     85.9       27.0     NaN
# 1982-05-01  25.689651     22.7     28.1     83.2       28.0     NaN

# %% [markdown]
# Findings:
# - The La Nina climate phenomenon, which brings more rain over equatorial South-east Asia, had been in effect for 2021 and 2007. 2021 was Singapore's second-wettest year on record due to La Nina climate phenomenon.
# -

# %% [markdown]
# Adding dengue data:

# %%
total_rdays_by_year = df_month['no_of_rainy_days'].groupby(df_month.index.year).sum().reset_index()
total_rdays_by_month = df_month['no_of_rainy_days'].groupby(df_month.index.month).sum().reset_index()

colors = sns.cubehelix_palette(start=2, rot=0, dark=0.2, light=0.8, reverse=False)

# Create the figure and two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))

# First subplot
sns.barplot(x='date', y='no_of_rainy_days', data=total_rdays_by_year, palette=colors, ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('Total Rainy Days')
ax1.set_title('Total Rainy Days per Year')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha='right')

# Second subplot (similar graph as the first one)
sns.barplot(x='date', y='no_of_rainy_days', data=total_rdays_by_month, palette=colors, ax=ax2)
ax2.set_xlabel('Month')
ax2.set_ylabel('Total Rainy Days')
ax2.set_title('Total Rainy Days per Month')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha='right')

# Adjust the spacing between subplots
fig.tight_layout()

# Display the plot
plt.show()

# %%
total_dengue_cases_by_year = df_month['dengue'].groupby(df_month.index.year).sum().reset_index()
total_dengue_cases_by_month = df_month['dengue'].groupby(df_month.index.month).sum().reset_index()

total_rdays_cases_by_year = df_month['no_of_rainy_days'].groupby(df_month.index.year).sum().reset_index()
total_rdays_cases_by_month = df_month['no_of_rainy_days'].groupby(df_month.index.month).sum().reset_index()


# Set style and color palette
sns.set(style='whitegrid')

# Create the figure and two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# First subplot
sns.lineplot(x='date', y='dengue', data=total_dengue_cases_by_year, label='Dengue Cases', ax=ax1)
sns.lineplot(x='date', y='no_of_rainy_days', data=total_rdays_cases_by_year, label='Total Rainy Days', ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('Count')
ax1.set_title('Dengue Cases and Total Rainy Days per Year')
ax1.legend()

# Second subplot (similar graph as the first one)
sns.lineplot(x='date', y='dengue', data=total_dengue_cases_by_month, label='Dengue Cases', ax=ax2)
sns.lineplot(x='date', y='no_of_rainy_days', data=total_rdays_cases_by_month, label='Total Rainy Days', ax=ax2)
ax2.set_xlabel('Year')
ax2.set_ylabel('Count')
ax2.set_title('Dengue Cases and Total Rainy Days per Month')
ax2.legend()

# Adjust the spacing between subplots
fig.tight_layout()

# Display the plot
plt.show()

# %%
total_dengue_rdays_by_year = df_month[['no_of_rainy_days', 'dengue']].groupby(df_month.index.year).sum().reset_index()
total_dengue_rdays_by_month = df_month[['no_of_rainy_days', 'dengue']].groupby(df_month.index.month).sum().reset_index()

# Set style
sns.set(style='whitegrid')

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Subplot 1: Scatter plot
sns.scatterplot(x='no_of_rainy_days', y='dengue', data=total_dengue_rdays_by_year, ax=axes[0])
axes[0].set_xlabel('Total Rainy Days')
axes[0].set_ylabel('Dengue Cases')
axes[0].set_title('Dengue Cases vs Total Rainy Days Yearly')

# Subplot 2: Scatter plot with different data
sns.scatterplot(x='no_of_rainy_days', y='dengue', data=total_dengue_rdays_by_month, ax=axes[1])
axes[1].set_xlabel('Total Rainy Days')
axes[1].set_ylabel('Dengue Cases')
axes[1].set_title('Dengue Cases vs Total Rainy Days Monthly')

# Adjust spacing between subplots
plt.tight_layout()

plt.show()

# %% [markdown]
# Use data in year 2019 only to plot the rain data VS dengue graphs as there is abnormally low dengue fever cases. This is because Covid-19 broke out and people did not want to leave the house. So, I want to see if there is still any correlation observed.

# %%
rdays_dengue_cases_2019 = df_month[df_month.index.year == 2019]

colors = sns.cubehelix_palette(start=2, rot=0, dark=0.2, light=0.8, reverse=False)

# Create the figure and two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# First subplot - Total Rainy Days per Month of 2019
sns.barplot(x=rdays_dengue_cases_2019.index.month, y='no_of_rainy_days', data=rdays_dengue_cases_2019, palette=colors, ax=axes[0])
axes[0].set_xlabel('Month')
axes[0].set_ylabel('Total Rainy Days')
axes[0].set_title('Total Rainy Days per Month of 2019')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45, ha='right')

# Second subplot - Total Rainfall per Month of 2019
sns.barplot(x=rdays_dengue_cases_2019.index.month, y='total_rainfall', data=rdays_dengue_cases_2019, palette=colors, ax=axes[1])
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Total Rainfall')
axes[1].set_title('Total Rainfall per Month of 2019')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=45, ha='right')

# Adjust the spacing between subplots
fig.tight_layout()

# Display the plot
plt.show()

# %%
# Set style and color palette
sns.set(style='whitegrid')

# Create the figure and two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# First subplot - Dengue Cases
sns.lineplot(x=rdays_dengue_cases_2019.index.month, y='dengue', data=rdays_dengue_cases_2019, label='Dengue Cases', ax=ax1)
sns.lineplot(x=rdays_dengue_cases_2019.index.month, y='no_of_rainy_days', data=rdays_dengue_cases_2019, label='Total Rainy Days', ax=ax1)
ax1.set_xlabel('Month')
ax1.set_ylabel('Dengue Cases')
ax1.set_title('Dengue Cases Per Month for 2019')

# Second subplot - Total Rainy Days
sns.lineplot(x=rdays_dengue_cases_2019.index.month, y='dengue', data=rdays_dengue_cases_2019, label='Dengue Cases', ax=ax2)
sns.lineplot(x=rdays_dengue_cases_2019.index.month, y='total_rainfall', data=rdays_dengue_cases_2019, label='Total Rairfall', ax=ax2)
ax2.set_xlabel('Month')
ax2.set_ylabel('Total Rainfall')
ax2.set_title('Total Rainfall Per Month for 2019')

# Adjust the spacing between subplots
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# **Which month have the highest and lowest number of rainy days in 1990, 2000, 2010 and 2020?**

# %%
for year in years:
    rainy_days_year = df_month.loc[df_month.index.year == year, 'no_of_rainy_days']
    max_rainy_days_month = rainy_days_year.idxmax().strftime('%B')
    min_rainy_days_month = rainy_days_year.idxmin().strftime('%B')
    print(f"For the year {year}:")
    print(f"Highest number of rainy days month: {max_rainy_days_month}")
    print(f"Lowest number of rainy days month: {min_rainy_days_month}")
    print()
# Out:
# For the year 1990:
# Highest number of rainy days month: September
# Lowest number of rainy days month: March
#
# For the year 2000:
# Highest number of rainy days month: November
# Lowest number of rainy days month: May
#
# For the year 2010:
# Highest number of rainy days month: November
# Lowest number of rainy days month: February
#
# For the year 2020:
# Highest number of rainy days month: July
# Lowest number of rainy days month: January

# %% [markdown]
# Findings:
# - The rainy season is usually near the 4th quarter of the year, but has gotten earlier in the past decade.
# - The dry season is usually in the 1st quarter of the year.
# - The dry and rainy season are usually 6 months apart.
# - These seasons generally coincides with the periods with highest/lowest rainfall as investigated earlier on.

# %% [markdown]
# **Which year have the highest and lowest number of rainy days in the date range of analysis?**

# %%
max_rainy_days_year = df_month['no_of_rainy_days'].groupby(df_month.index.year).sum().idxmax()
min_rainy_days_year = df_month['no_of_rainy_days'].groupby(df_month.index.year).sum().idxmin()

print(f"Highest number of rainy days year in the date range: {max_rainy_days_year}")
print(f"Lowest number of rainy days year in the date range: {min_rainy_days_year}")
# Out:
# Highest number of rainy days year in the date range: 2013
# Lowest number of rainy days year in the date range: 1997

# %% [markdown]
# **Are there any outliers months in the dataset?**

# %% [markdown]
# Using the z-score method, a month is considered as an outlier if its total rainfall is more than three standard deviations away from the mean

# %%
# Checking the 2 key datasets: total_rainfall and no_of_rainy_days

outlier_threshold = 3

# Total _rainfall
z_scores = (df_month['total_rainfall'] - df_month['total_rainfall'].mean()) / df_month['total_rainfall'].std()
# Using masking to show rows of outlier months
outliers = df_month[z_scores.abs() > outlier_threshold]
# Sorting the column in descending order
outliers.sort_values(by=['total_rainfall'], ascending=False, inplace=True)
print(f"Mean: {df_month['total_rainfall'].mean()}")
display(outliers[['total_rainfall']])

# no_of_rainy_days
z_scores_days = (df_month['no_of_rainy_days'] - df_month['no_of_rainy_days'].mean()) / df_month['no_of_rainy_days'].std()
# Using masking to show rows of outlier months
outliers_days = df_month[z_scores.abs() > outlier_threshold]
# Sorting the column in descending order
outliers_days.sort_values(by=['no_of_rainy_days'], ascending=False, inplace=True)
print(f"Mean: {df_month['no_of_rainy_days'].mean()}")
display(outliers_days[['no_of_rainy_days']])
# Out:
# Mean: 177.1637295081967
# C:\Users\jinji\AppData\Local\Temp\ipykernel_57444\2897640749.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers.sort_values(by=['total_rainfall'], ascending=False, inplace=True)
#             total_rainfall
# date
# 2006-12-01           765.9
# 2021-01-01           692.8
# 2001-12-01           609.0
# 2004-01-01           600.9
# 1987-01-01           568.6
# Mean: 14.061475409836065
# C:\Users\jinji\AppData\Local\Temp\ipykernel_57444\2897640749.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_days.sort_values(by=['no_of_rainy_days'], ascending=False, inplace=True)
#             no_of_rainy_days
# date
# 2006-12-01              22.0
# 2001-12-01              20.0
# 2021-01-01              17.0
# 1987-01-01              16.0
# 2004-01-01              13.0

# %% [markdown]
# Findings:
# - The outliers are usually abnormal high amounts of rainfall/number of rainy days in December and January. This could be attributed to the extremely high intensity of The Northeast Monsoon that usually occurs from December to early March, which brings a spike in total rainfall in that month.

# %% [markdown]
# ## Visualize the Data

# %% [markdown]
# Some ideas for plots that can be generated:
#
# - Plot the histogram of the rainfall data with various bins and comment on the distribution of the data - is it centered, skewed?
# - Plot the box-and-whiskers plot. Comment on the different quartiles and identify any outliers in the dataset.
# - Is there a correlation between the number of rainy days and total rainfall in the month? What kind of correlation do your suspect? Does the graph show the same?

# %% [markdown]
# **Correlations**

# %%
#Moving dengue cases to first column
display(df_year.head())
df_year= pd.concat([df_year['dengue_case'], df_year.iloc[:,0:-1]], axis=1) 
display(df_year.head())
# Out:
#       mean_max_rain  min_max_rain  max_max_rain  total_rday_mean
# date
# 1982      38.150000           9.4         109.0        10.833333  \
# 1983      57.891667           5.1         181.8        12.083333
# 1984      66.758333          22.5         154.4        15.916667
# 1985      32.016667           9.9          86.8        15.083333
# 1986      59.933333          23.0         131.7        14.500000
#
#       total_rday_min  total_rday_max  total_rday_sum  total_rain_mean
# date
# 1982             5.0            21.0           130.0       131.808333  \
# 1983             2.0            18.0           145.0       166.141667
# 1984            11.0            22.0           191.0       223.891667
# 1985             7.0            22.0           181.0       123.658333
# 1986             2.0            22.0           174.0       211.341667
#
#       total_rain_min  total_rain_max  total_rain_sum   wbt_mean  wbt_min_min
# date
# 1982            27.8           494.1          1581.7  24.921417         21.3  \
# 1983             5.6           370.6          1993.7  25.234144         21.0
# 1984           102.7           470.4          2686.7  24.721475         21.0
# 1985            37.0           340.1          1483.9  24.857212         20.9
# 1986            26.7           396.0          2536.1  24.802940         21.3
#
#       wbt_max    rh_mean  temp_mean  dengue_case
# date
# 1982     28.1  81.966667  27.358333        216.0
# 1983     28.1  82.283333  27.666667        205.0
# 1984     27.5  84.616667  26.766667         86.0
# 1985     28.3  83.208333  27.116667        126.0
# 1986     27.8  82.866667  27.100000        354.0
#       dengue_case  mean_max_rain  min_max_rain  max_max_rain  total_rday_mean
# date
# 1982        216.0      38.150000           9.4         109.0        10.833333  \
# 1983        205.0      57.891667           5.1         181.8        12.083333
# 1984         86.0      66.758333          22.5         154.4        15.916667
# 1985        126.0      32.016667           9.9          86.8        15.083333
# 1986        354.0      59.933333          23.0         131.7        14.500000
#
#       total_rday_min  total_rday_max  total_rday_sum  total_rain_mean
# date
# 1982             5.0            21.0           130.0       131.808333  \
# 1983             2.0            18.0           145.0       166.141667
# 1984            11.0            22.0           191.0       223.891667
# 1985             7.0            22.0           181.0       123.658333
# 1986             2.0            22.0           174.0       211.341667
#
#       total_rain_min  total_rain_max  total_rain_sum   wbt_mean  wbt_min_min
# date
# 1982            27.8           494.1          1581.7  24.921417         21.3  \
# 1983             5.6           370.6          1993.7  25.234144         21.0
# 1984           102.7           470.4          2686.7  24.721475         21.0
# 1985            37.0           340.1          1483.9  24.857212         20.9
# 1986            26.7           396.0          2536.1  24.802940         21.3
#
#       wbt_max    rh_mean  temp_mean
# date
# 1982     28.1  81.966667  27.358333
# 1983     28.1  82.283333  27.666667
# 1984     27.5  84.616667  26.766667
# 1985     28.3  83.208333  27.116667
# 1986     27.8  82.866667  27.100000

# %%
# Correlation matric is sorted based on 
display(df_year.corr().sort_values(by='dengue_cases',ascending=False));
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df_year.corr().sort_values(by='dengue_cases',ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);

save_results_to = '../data/output/'
plt.savefig(save_results_to + 'heatmap_yearly.png', dpi = 300, bbox_inches='tight')

# plt.savefig(result_dir + sample_file_name, dpi=300, bbox_inches='tight')

# https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e
# Out:
#                            dengue_cases  mean_monthly_max_rainfall
# dengue_cases                   1.000000                  -0.205953  \
# temp_mean                      0.522948                  -0.363255
# max_monthly_rday               0.033958                  -0.032019
# mean_monthly_rday              0.031854                   0.438356
# total_rday                     0.031854                   0.438356
# wbt_mean                      -0.009393                   0.215727
# wbt_min_min                   -0.035316                   0.092550
# min_monthly_rainfall          -0.053875                   0.402805
# wbt_max                       -0.105428                   0.378838
# min_monthly_max_rainfall      -0.128599                   0.385883
# min_monthly_rday              -0.128608                   0.240315
# mean_monthly_rainfall         -0.153415                   0.851985
# total_rainfall                -0.153415                   0.851985
# mean_monthly_max_rainfall     -0.205953                   1.000000
# max_monthly_rainfall          -0.254119                   0.536138
# max_monthly_max_rainfall      -0.273479                   0.844468
# rh_mean                       -0.581993                   0.569830
#
#                            min_monthly_max_rainfall  max_monthly_max_rainfall
# dengue_cases                              -0.128599                 -0.273479  \
# temp_mean                                 -0.509674                 -0.331235
# max_monthly_rday                          -0.025017                 -0.097133
# mean_monthly_rday                          0.510424                  0.229468
# total_rday                                 0.510424                  0.229468
# wbt_mean                                   0.020007                  0.169121
# wbt_min_min                                0.062843                  0.033299
# min_monthly_rainfall                       0.814017                  0.129974
# wbt_max                                   -0.070003                  0.452870
# min_monthly_max_rainfall                   1.000000                  0.190978
# min_monthly_rday                           0.622770                  0.153478
# mean_monthly_rainfall                      0.573473                  0.612642
# total_rainfall                             0.573473                  0.612642
# mean_monthly_max_rainfall                  0.385883                  0.844468
# max_monthly_rainfall                       0.264813                  0.651422
# max_monthly_max_rainfall                   0.190978                  1.000000
# rh_mean                                    0.564678                  0.495336
#
#                            mean_monthly_rday  min_monthly_rday
# dengue_cases                        0.031854         -0.128608  \
# temp_mean                          -0.313951         -0.334823
# max_monthly_rday                    0.402403         -0.053722
# mean_monthly_rday                   1.000000          0.526604
# total_rday                          1.000000          0.526604
# wbt_mean                            0.072458          0.044610
# wbt_min_min                         0.010462         -0.098275
# min_monthly_rainfall                0.522151          0.665672
# wbt_max                             0.049522         -0.063634
# min_monthly_max_rainfall            0.510424          0.622770
# min_monthly_rday                    0.526604          1.000000
# mean_monthly_rainfall               0.706735          0.377027
# total_rainfall                      0.706735          0.377027
# mean_monthly_max_rainfall           0.438356          0.240315
# max_monthly_rainfall                0.091082          0.097966
# max_monthly_max_rainfall            0.229468          0.153478
# rh_mean                             0.395185          0.399930
#
#                            max_monthly_rday  total_rday
# dengue_cases                       0.033958    0.031854  \
# temp_mean                          0.053862   -0.313951
# max_monthly_rday                   1.000000    0.402403
# mean_monthly_rday                  0.402403    1.000000
# total_rday                         0.402403    1.000000
# wbt_mean                           0.043666    0.072458
# wbt_min_min                        0.144962    0.010462
# min_monthly_rainfall              -0.087643    0.522151
# wbt_max                           -0.034545    0.049522
# min_monthly_max_rainfall          -0.025017    0.510424
# min_monthly_rday                  -0.053722    0.526604
# mean_monthly_rainfall              0.126658    0.706735
# total_rainfall                     0.126658    0.706735
# mean_monthly_max_rainfall         -0.032019    0.438356
# max_monthly_rainfall               0.039013    0.091082
# max_monthly_max_rainfall          -0.097133    0.229468
# rh_mean                           -0.025987    0.395185
#
#                            mean_monthly_rainfall  min_monthly_rainfall
# dengue_cases                           -0.153415             -0.053875  \
# temp_mean                              -0.408071             -0.504466
# max_monthly_rday                        0.126658             -0.087643
# mean_monthly_rday                       0.706735              0.522151
# total_rday                              0.706735              0.522151
# wbt_mean                                0.145233             -0.031857
# wbt_min_min                             0.094528             -0.043769
# min_monthly_rainfall                    0.579363              1.000000
# wbt_max                                 0.332561             -0.093397
# min_monthly_max_rainfall                0.573473              0.814017
# min_monthly_rday                        0.377027              0.665672
# mean_monthly_rainfall                   1.000000              0.579363
# total_rainfall                          1.000000              0.579363
# mean_monthly_max_rainfall               0.851985              0.402805
# max_monthly_rainfall                    0.553081              0.178707
# max_monthly_max_rainfall                0.612642              0.129974
# rh_mean                                 0.553282              0.513036
#
#                            max_monthly_rainfall  total_rainfall  wbt_mean
# dengue_cases                          -0.254119       -0.153415 -0.009393  \
# temp_mean                             -0.227910       -0.408071  0.483632
# max_monthly_rday                       0.039013        0.126658  0.043666
# mean_monthly_rday                      0.091082        0.706735  0.072458
# total_rday                             0.091082        0.706735  0.072458
# wbt_mean                               0.089422        0.145233  1.000000
# wbt_min_min                            0.209797        0.094528  0.607673
# min_monthly_rainfall                   0.178707        0.579363 -0.031857
# wbt_max                                0.394807        0.332561  0.660520
# min_monthly_max_rainfall               0.264813        0.573473  0.020007
# min_monthly_rday                       0.097966        0.377027  0.044610
# mean_monthly_rainfall                  0.553081        1.000000  0.145233
# total_rainfall                         0.553081        1.000000  0.145233
# mean_monthly_max_rainfall              0.536138        0.851985  0.215727
# max_monthly_rainfall                   1.000000        0.553081  0.089422
# max_monthly_max_rainfall               0.651422        0.612642  0.169121
# rh_mean                                0.309426        0.553282  0.313196
#
#                            wbt_min_min   wbt_max   rh_mean  temp_mean
# dengue_cases                 -0.035316 -0.105428 -0.581993   0.522948
# temp_mean                     0.230078  0.264079 -0.679145   1.000000
# max_monthly_rday              0.144962 -0.034545 -0.025987   0.053862
# mean_monthly_rday             0.010462  0.049522  0.395185  -0.313951
# total_rday                    0.010462  0.049522  0.395185  -0.313951
# wbt_mean                      0.607673  0.660520  0.313196   0.483632
# wbt_min_min                   1.000000  0.412171  0.262077   0.230078
# min_monthly_rainfall         -0.043769 -0.093397  0.513036  -0.504466
# wbt_max                       0.412171  1.000000  0.254776   0.264079
# min_monthly_max_rainfall      0.062843 -0.070003  0.564678  -0.509674
# min_monthly_rday             -0.098275 -0.063634  0.399930  -0.334823
# mean_monthly_rainfall         0.094528  0.332561  0.553282  -0.408071
# total_rainfall                0.094528  0.332561  0.553282  -0.408071
# mean_monthly_max_rainfall     0.092550  0.378838  0.569830  -0.363255
# max_monthly_rainfall          0.209797  0.394807  0.309426  -0.227910
# max_monthly_max_rainfall      0.033299  0.452870  0.495336  -0.331235
# rh_mean                       0.262077  0.254776  1.000000  -0.679145

# %% [markdown]
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
#Lineplots


fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')

axs[0].plot(df_year['no_of_rainy_days_mean'])
plt.figure(figsize = (60,20))
plt.plot(df_year)
plt.title('Dengue Cases from 2019 to 2020 W36', fontsize = 50)
plt.xlabel('Year', fontsize = 50)
plt.ylabel('Number of Cases', fontsize = 50)

axs[1].plot(df_year['Dengue/DHF'])
plt.figure(figsize = (60,20))
plt.plot(df_year)
plt.title('Dengue Cases from 2019 to 2020 W36', fontsize = 50)
plt.xlabel('Year', fontsize = 50)
plt.ylabel('Number of Cases', fontsize = 50)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %%
sns.pairplot(df_year)

# %% [markdown]
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels

# %% [markdown]
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable

# %% [markdown]
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Limitations of data collection**
#
# - Monthly data for dengue fever only spans over a few year.
# - We have yearly dengue fever data but it does not show monthly data
#
# - Not easy to obtain cluster data. Existing ones has to be scraped

# %% [markdown]
# https://www.channelnewsasia.com/asia/dengue-fever-plummet-southeast-asia-2021-covid-19-lockdown-1949581
#
# “Unfortunately, COVID-19 has impacted a range of routine health-related programmes in many countries.
#
# “Detection and reporting of dengue cases are also believed to have been impacted by reduced access to health facilities, and a hesitancy to seek medical care at facilities due to concern of possible exposure to COVID-19 patients,” the spokesperson added.
#
# Possible conclusion and recommendations:
# --> Take note of dengure cases after high rainfall season, esp after (how many) weeks
# --> Wolfbachia mosquitoes - raining season may affect too
# --> Paired with the above seasons, take note to still take care of the dengue fever cases during pandemic, special ocassions
